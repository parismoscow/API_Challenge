# %% [markdown]
# WeatherPy Analysis
#
# As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth. There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness. There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# Note
#
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
# Import API key
from config import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint
import json
import csv
import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
params = {"appid": api_key}

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
cities_df = pd.DataFrame()
cities_df['lats'] = np.random.uniform(low=-90.000, high=90.000, size=1500)
cities_df['lngs'] = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(cities_df['lats'], cities_df['lngs'])
cities_df['City'] = ""
cities_df['Country'] = ""

# %%
for index, row in cities_df.iterrows():
    lat = row['lats']
    lng = row['lngs']
    cities_df.set_value(index, 'City', citipy.nearest_city(lat, lng).city_name)
    cities_df.set_value(index, 'Country', citipy.nearest_city(lat, lng).country_code)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """

# %%
cities_df.head()
# Out:
#         lats        lngs            City Country
# 0 -68.473562   70.579877  saint-philippe      re
# 1 -40.862869  114.384738          albany      au
# 2 -26.446967 -161.858019          avarua      ck
# 3  -6.408103   -3.609454       jamestown      sh
# 4 -83.950788  -10.346820        hermanus      za

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# Export the city data into a .csv.
# Display the DataFrame

# %%
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      598
# lats       598
# lngs       598
# City       598
# Country    598
# dtype: int64

# %%
cities_df['City']
# Out:
# 0         saint-philippe
# 1                 albany
# 2                 avarua
# 3              jamestown
# 4               hermanus
# 5                   ures
# 6                rikitea
# 7                 hasaki
# 8                  ambon
# 9                  bowen
# 10                   bud
# 11               angoche
# 12                 rundu
# 13               mataura
# 14              thompson
# 15     sao joao da barra
# 16                mehamn
# 17           provideniya
# 18                faanui
# 19               butembo
# 20                 vaini
# 21                  asau
# 22               qaanaaq
# 23             mahebourg
# 24            rio grande
# 25              tasiilaq
# 26          constitucion
# 27                atuona
# 28              atherton
# 29               cayenne
#              ...
# 568            kysyl-syr
# 569              magadan
# 570          novyy urgal
# 571               pangai
# 572              solwezi
# 573               palmer
# 574             tarudant
# 575          reconquista
# 576              barabai
# 577            prokuplje
# 578               dakoro
# 579             nalagarh
# 580                sabla
# 581                 adra
# 582             waingapu
# 583            shuyskoye
# 584             tambovka
# 585        alice springs
# 586                aldan
# 587               sorong
# 588                 olot
# 589            cheuskiny
# 590            namatanai
# 591     puerto escondido
# 592               guilin
# 593               urucui
# 594              ushtobe
# 595                kieta
# 596         villaviciosa
# 597                lishu
# Name: City, Length: 598, dtype: object

# %%
# city_list = cities_df['City'].tolist()
# city_list

# %% [markdown]
# ### Perform API Calls

# %%
# column_names = ["City",  
#                 "Country",
#                 "Temperature",
#                 "Latitude",
#                 "Longitude",
#                 "Humidity",
#                 "Cloudiness",
#                 "Wind Speed",
#                 "Date"
#                ]
new_cities_df = pd.DataFrame()

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=imperial" + "&q=" + target_city
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        new_cities_df.set_value(index, "City", city_data["name"])
        new_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        new_cities_df.set_value(index, "Temperature", city_data["main"]["temp"])
        new_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        new_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        new_cities_df.set_value(index, "Humidity", city_data["main"]["humidity"])
        new_cities_df.set_value(index, "Cloudiness", city_data["clouds"]["all"])
        new_cities_df.set_value(index, "Wind Speed", city_data["wind"]["speed"])
        new_cities_df.set_value(index, "Date", city_data['dt'])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=saint-philippe
# ------------------------
# Proceesing: City #  2  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=albany
# ------------------------
# Proceesing: City #  3  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=avarua
# ------------------------
# Proceesing: City #  4  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jamestown
# ------------------------
# Proceesing: City #  5  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hermanus
# ------------------------
# Proceesing: City #  6  |  Ures MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ures
# ------------------------
# Proceesing: City #  7  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=rikitea
# ------------------------
# Proceesing: City #  8  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hasaki
# ------------------------
# Proceesing: City #  9  |  Ambon FR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ambon
# ------------------------
# Proceesing: City #  10  |  Bowen AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bowen
# ------------------------
# Proceesing: City #  11  |  Bud NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bud
# ------------------------
# Proceesing: City #  12  |  Angoche MZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=angoche
# ------------------------
# Proceesing: City #  13  |  Rundu NA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=rundu
# ------------------------
# Proceesing: City #  14  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mataura
# ------------------------
# Proceesing: City #  15  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=thompson
# ------------------------
# Proceesing: City #  16  |  Sao Joao da Barra BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sao joao da barra
# ------------------------
# Proceesing: City #  17  |  Mehamn NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mehamn
# ------------------------
# Proceesing: City #  18  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=provideniya
# ------------------------
# Proceesing: City #  19  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=faanui
# ------------------------
# Proceesing: City #  20  |  Butembo CD
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=butembo
# ------------------------
# Proceesing: City #  21  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=vaini
# City not found, skipping...
# ------------------------
# Proceesing: City #  22  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=qaanaaq
# ------------------------
# Proceesing: City #  23  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mahebourg
# ------------------------
# Proceesing: City #  24  |  Rio Grande BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=rio grande
# ------------------------
# Proceesing: City #  25  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tasiilaq
# ------------------------
# Proceesing: City #  26  |  Constitucion MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=constitucion
# ------------------------
# Proceesing: City #  27  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=atuona
# ------------------------
# Proceesing: City #  28  |  Atherton GB
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=atherton
# ------------------------
# Proceesing: City #  29  |  Cayenne GF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cayenne
# ------------------------
# Proceesing: City #  30  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port alfred
# ------------------------
# Proceesing: City #  31  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=east london
# City not found, skipping...
# ------------------------
# Proceesing: City #  32  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=alofi
# City not found, skipping...
# ------------------------
# Proceesing: City #  33  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=butaritari
# ------------------------
# Proceesing: City #  34  |  Umea SE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=umea
# ------------------------
# Proceesing: City #  35  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ushuaia
# City not found, skipping...
# ------------------------
# Proceesing: City #  36  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mar del plata
# City not found, skipping...
# ------------------------
# Proceesing: City #  37  |  Marawi PH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=marawi
# ------------------------
# Proceesing: City #  38  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=quatre cocos
# City not found, skipping...
# ------------------------
# Proceesing: City #  39  |  Grindavik IS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=grindavik
# ------------------------
# Proceesing: City #  40  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=dikson
# ------------------------
# Proceesing: City #  41  |  Kampong Thum KH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kampong thum
# ------------------------
# Proceesing: City #  42  |  Turhal TR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=turhal
# City not found, skipping...
# ------------------------
# Proceesing: City #  43  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cape town
# ------------------------
# Proceesing: City #  44  |  Polunochnoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=polunochnoye
# City not found, skipping...
# ------------------------
# Proceesing: City #  45  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=punta arenas
# ------------------------
# Proceesing: City #  46  |  Jining CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jining
# ------------------------
# Proceesing: City #  47  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=puerto ayora
# ------------------------
# Proceesing: City #  48  |  Valparaiso US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=valparaiso
# ------------------------
# Proceesing: City #  49  |  Pasni PK
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pasni
# ------------------------
# Proceesing: City #  50  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=arraial do cabo
# ------------------------
# Proceesing: City #  51  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=busselton
# ------------------------
# Proceesing: City #  52  |  Merrill US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=merrill
# ------------------------
# Proceesing: City #  53  |  Ararat AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ararat
# ------------------------
# Proceesing: City #  54  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=torbay
# ------------------------
# Proceesing: City #  55  |  Grand Gaube MU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=grand gaube
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  56  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=barrow
# ------------------------
# Proceesing: City #  57  |  Te Anau NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=te anau
# ------------------------
# Proceesing: City #  58  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ponta do sol
# ------------------------
# Proceesing: City #  59  |  Srednekolymsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=srednekolymsk
# City not found, skipping...
# ------------------------
# Proceesing: City #  60  |  Svetlogorsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=svetlogorsk
# ------------------------
# Proceesing: City #  61  |  Cabedelo BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cabedelo
# ------------------------
# Proceesing: City #  62  |  Harper US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=harper
# ------------------------
# Proceesing: City #  63  |  Puerto Suarez BO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=puerto suarez
# ------------------------
# Proceesing: City #  64  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bluff
# ------------------------
# Proceesing: City #  65  |  Muroto JP
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=muroto
# ------------------------
# Proceesing: City #  66  |  Concarneau FR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=concarneau
# ------------------------
# Proceesing: City #  67  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=yellowknife
# ------------------------
# Proceesing: City #  68  |  Camacha PT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=camacha
# ------------------------
# Proceesing: City #  69  |  Varnavino RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=varnavino
# ------------------------
# Proceesing: City #  70  |  Laguna MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=laguna
# ------------------------
# Proceesing: City #  71  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=new norfolk
# ------------------------
# Proceesing: City #  72  |  Bulungu CD
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bulungu
# City not found, skipping...
# ------------------------
# Proceesing: City #  73  |  Arinos BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=arinos
# ------------------------
# Proceesing: City #  74  |  Dunedin NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=dunedin
# ------------------------
# Proceesing: City #  75  |  Poronaysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=poronaysk
# ------------------------
# Proceesing: City #  76  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lompoc
# ------------------------
# Proceesing: City #  77  |  Magadi IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=magadi
# City not found, skipping...
# ------------------------
# Proceesing: City #  78  |  Nome US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nome
# ------------------------
# Proceesing: City #  79  |  El Limon VE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=el limon
# ------------------------
# Proceesing: City #  80  |  Jadu LY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jadu
# ------------------------
# Proceesing: City #  81  |  Naryan-Mar RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=naryan-mar
# ------------------------
# Proceesing: City #  82  |  Moa CU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=moa
# ------------------------
# Proceesing: City #  83  |  Naze NG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=naze
# ------------------------
# Proceesing: City #  84  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=severo-kurilsk
# ------------------------
# Proceesing: City #  85  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ostrovnoy
# ------------------------
# Proceesing: City #  86  |  Sonqor IR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sonqor
# ------------------------
# Proceesing: City #  87  |  Kotaparh IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kotaparh
# ------------------------
# Proceesing: City #  88  |  Sibolga ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sibolga
# ------------------------
# Proceesing: City #  89  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=klaksvik
# ------------------------
# Proceesing: City #  90  |  Liverpool GB
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=liverpool
# ------------------------
# Proceesing: City #  91  |  Mareeba AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mareeba
# City not found, skipping...
# ------------------------
# Proceesing: City #  92  |  Belmonte PT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=belmonte
# ------------------------
# Proceesing: City #  93  |  Omboue GA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=omboue
# ------------------------
# Proceesing: City #  94  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bredasdorp
# ------------------------
# Proceesing: City #  95  |  Tura IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tura
# ------------------------
# Proceesing: City #  96  |  Kaeo NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kaeo
# City not found, skipping...
# ------------------------
# Proceesing: City #  97  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hilo
# ------------------------
# Proceesing: City #  98  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=talnakh
# ------------------------
# Proceesing: City #  99  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ilulissat
# ------------------------
# Proceesing: City #  100  |  Sainte-Maxime FR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sainte-maxime
# ------------------------
# Proceesing: City #  101  |  Gat SN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=gat
# ------------------------
# Proceesing: City #  102  |  Jauja PE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jauja
# ------------------------
# Proceesing: City #  103  |  Beira ES
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=beira
# ------------------------
# Proceesing: City #  104  |  Whitehorse CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=whitehorse
# ------------------------
# Proceesing: City #  105  |  Xining CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=xining
# ------------------------
# Proceesing: City #  106  |  Cienfuegos CU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cienfuegos
# ------------------------
# Proceesing: City #  107  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=longyearbyen
# City not found, skipping...
# ------------------------
# Proceesing: City #  108  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hobart
# ------------------------
# Proceesing: City #  109  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kruisfontein
# ------------------------
# Proceesing: City #  110  |  Point Fortin TT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=point fortin
# ------------------------
# Proceesing: City #  111  |  Prince Rupert CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=prince rupert
# ------------------------
# Proceesing: City #  112  |  Podor MR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=podor
# ------------------------
# Proceesing: City #  113  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pisco
# ------------------------
# Proceesing: City #  114  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port elizabeth
# ------------------------
# Proceesing: City #  115  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=carnarvon
# ------------------------
# Proceesing: City #  116  |  Jasper US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jasper
# ------------------------
# Proceesing: City #  117  |  Sechura PE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sechura
# ------------------------
# Proceesing: City #  118  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cherskiy
# ------------------------
# Proceesing: City #  119  |  Campoverde IT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=campoverde
# ------------------------
# Proceesing: City #  120  |  Kogon UZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kogon
# ------------------------
# Proceesing: City #  121  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=rawson
# ------------------------
# Proceesing: City #  122  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=taoudenni
# ------------------------
# Proceesing: City #  123  |  Maragogi BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=maragogi
# ------------------------
# Proceesing: City #  124  |  Nizhniy Baskunchak RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nizhniy baskunchak
# ------------------------
# Proceesing: City #  125  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kahului
# ------------------------
# Proceesing: City #  126  |  Zhireken RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=zhireken
# ------------------------
# Proceesing: City #  127  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kodiak
# ------------------------
# Proceesing: City #  128  |  Doha QA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=doha
# ------------------------
# Proceesing: City #  129  |  Muisne EC
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=muisne
# ------------------------
# Proceesing: City #  130  |  Faya SA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=faya
# ------------------------
# Proceesing: City #  131  |  Okhotsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=okhotsk
# ------------------------
# Proceesing: City #  132  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=namibe
# City not found, skipping...
# ------------------------
# Proceesing: City #  133  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sitka
# ------------------------
# Proceesing: City #  134  |  Monteagudo BO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=monteagudo
# ------------------------
# Proceesing: City #  135  |  Valle de Angeles HN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=valle de angeles
# ------------------------
# Proceesing: City #  136  |  Filadelfia PY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=filadelfia
# ------------------------
# Proceesing: City #  137  |  North Bend US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=north bend
# City not found, skipping...
# ------------------------
# Proceesing: City #  138  |  Beringovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=beringovskiy
# ------------------------
# Proceesing: City #  139  |  Hami CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hami
# ------------------------
# Proceesing: City #  140  |  Beatrice US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=beatrice
# ------------------------
# Proceesing: City #  141  |  Phangnga TH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=phangnga
# ------------------------
# Proceesing: City #  142  |  Calvinia ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=calvinia
# ------------------------
# Proceesing: City #  143  |  Marzuq YE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=marzuq
# City not found, skipping...
# ------------------------
# Proceesing: City #  144  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=khatanga
# ------------------------
# Proceesing: City #  145  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lebu
# ------------------------
# Proceesing: City #  146  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=vila franca do campo
# ------------------------
# Proceesing: City #  147  |  Dongsheng CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=dongsheng
# City not found, skipping...
# ------------------------
# Proceesing: City #  148  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hithadhoo
# ------------------------
# Proceesing: City #  149  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=coquimbo
# ------------------------
# Proceesing: City #  150  |  Mayo CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mayo
# ------------------------
# Proceesing: City #  151  |  Shingu JP
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=shingu
# ------------------------
# Proceesing: City #  152  |  Port Lincoln AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port lincoln
# ------------------------
# Proceesing: City #  153  |  Hambantota LK
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hambantota
# ------------------------
# Proceesing: City #  154  |  Sinnamary GF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sinnamary
# ------------------------
# Proceesing: City #  155  |  Sal Rei CV
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sal rei
# ------------------------
# Proceesing: City #  156  |  Miandrivazo MG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=miandrivazo
# ------------------------
# Proceesing: City #  157  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ribeira grande
# ------------------------
# Proceesing: City #  158  |  Cartagena ES
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cartagena
# ------------------------
# Proceesing: City #  159  |  Half Moon Bay US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=half moon bay
# ------------------------
# Proceesing: City #  160  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  161  |  Erechim BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=erechim
# ------------------------
# Proceesing: City #  162  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=katsuura
# ------------------------
# Proceesing: City #  163  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tiksi
# ------------------------
# Proceesing: City #  164  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=chokurdakh
# ------------------------
# Proceesing: City #  165  |  Hirara JP
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hirara
# ------------------------
# Proceesing: City #  166  |  Broken Hill AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=broken hill
# ------------------------
# Proceesing: City #  167  |  Teahupoo PF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=teahupoo
# ------------------------
# Proceesing: City #  168  |  Banda Aceh ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=banda aceh
# ------------------------
# Proceesing: City #  169  |  Mitsamiouli KM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mitsamiouli
# ------------------------
# Proceesing: City #  170  |  Ignatovka RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ignatovka
# ------------------------
# Proceesing: City #  171  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=cidreira
# ------------------------
# Proceesing: City #  172  |  Hofn IS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hofn
# ------------------------
# Proceesing: City #  173  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=victoria
# ------------------------
# Proceesing: City #  174  |  Hella IS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hella
# ------------------------
# Proceesing: City #  175  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=norman wells
# City not found, skipping...
# ------------------------
# Proceesing: City #  176  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lavrentiya
# ------------------------
# Proceesing: City #  177  |  Roald NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=roald
# ------------------------
# Proceesing: City #  178  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=caravelas
# ------------------------
# Proceesing: City #  179  |  Fomboni KM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=fomboni
# ------------------------
# Proceesing: City #  180  |  Vyazemskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=vyazemskiy
# ------------------------
# Proceesing: City #  181  |  Nuevo Progreso US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nuevo progreso
# City not found, skipping...
# ------------------------
# Proceesing: City #  182  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ahipara
# ------------------------
# Proceesing: City #  183  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=airai
# ------------------------
# Proceesing: City #  184  |  Tual ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tual
# ------------------------
# Proceesing: City #  185  |  High Level CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=high level
# ------------------------
# Proceesing: City #  186  |  Sept-Iles CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sept-iles
# City not found, skipping...
# ------------------------
# Proceesing: City #  187  |  Gao ML
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=gao
# ------------------------
# Proceesing: City #  188  |  Marsa Matruh EG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=marsa matruh
# ------------------------
# Proceesing: City #  189  |  Timbuktu ML
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tombouctou
# ------------------------
# Proceesing: City #  190  |  Waterloo CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=waterloo
# ------------------------
# Proceesing: City #  191  |  Bilma NE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bilma
# ------------------------
# Proceesing: City #  192  |  Scarborough GB
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=scarborough
# ------------------------
# Proceesing: City #  193  |  Christchurch NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=christchurch
# ------------------------
# Proceesing: City #  194  |  Richards Bay ZA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=richards bay
# ------------------------
# Proceesing: City #  195  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kaitangata
# ------------------------
# Proceesing: City #  196  |  Kayes ML
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kayes
# ------------------------
# Proceesing: City #  197  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=adrar
# ------------------------
# Proceesing: City #  198  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bambous virieux
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  199  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tuatapere
# ------------------------
# Proceesing: City #  200  |  Tabas IR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tabas
# ------------------------
# Proceesing: City #  201  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kapaa
# ------------------------
# Proceesing: City #  202  |  Huarmey PE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=huarmey
# ------------------------
# Proceesing: City #  203  |  Mount Isa AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mount isa
# ------------------------
# Proceesing: City #  204  |  Touros BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=touros
# ------------------------
# Proceesing: City #  205  |  Waddan LY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=waddan
# ------------------------
# Proceesing: City #  206  |  Pangnirtung CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pangnirtung
# ------------------------
# Proceesing: City #  207  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bethel
# ------------------------
# Proceesing: City #  208  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=geraldton
# ------------------------
# Proceesing: City #  209  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=iqaluit
# City not found, skipping...
# ------------------------
# Proceesing: City #  210  |  Karratha AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=karratha
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  211  |  Bara NG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bara
# ------------------------
# Proceesing: City #  212  |  Yerofey Pavlovich RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=yerofey pavlovich
# ------------------------
# Proceesing: City #  213  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=meulaboh
# ------------------------
# Proceesing: City #  214  |  Jinchang CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=jinchang
# ------------------------
# Proceesing: City #  215  |  Caceres CO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=caceres
# ------------------------
# Proceesing: City #  216  |  Petropavlovsk-Kamchatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=petropavlovsk-kamchatskiy
# City not found, skipping...
# ------------------------
# Proceesing: City #  217  |  Sioux Lookout CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sioux lookout
# ------------------------
# Proceesing: City #  218  |  Mana RS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mana
# ------------------------
# Proceesing: City #  219  |  Acapulco MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=acapulco
# City not found, skipping...
# ------------------------
# Proceesing: City #  220  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=fortuna
# ------------------------
# Proceesing: City #  221  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=souillac
# ------------------------
# Proceesing: City #  222  |  Pitimbu BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pitimbu
# City not found, skipping...
# ------------------------
# Proceesing: City #  223  |  Sergeyevka KZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sergeyevka
# ------------------------
# Proceesing: City #  224  |  Sovetskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sovetskiy
# ------------------------
# Proceesing: City #  225  |  Pacific Grove US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pacific grove
# ------------------------
# Proceesing: City #  226  |  Fairbanks US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=fairbanks
# ------------------------
# Proceesing: City #  227  |  Dicabisagan PH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=dicabisagan
# ------------------------
# Proceesing: City #  228  |  Bondo CD
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=bondo
# City not found, skipping...
# ------------------------
# Proceesing: City #  229  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=upernavik
# ------------------------
# Proceesing: City #  230  |  Daru SL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=daru
# City not found, skipping...
# ------------------------
# Proceesing: City #  231  |  Tessalit ML
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tessalit
# ------------------------
# Proceesing: City #  232  |  Petropavlovskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=petropavlovskoye
# ------------------------
# Proceesing: City #  233  |  Teeli RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=teeli
# ------------------------
# Proceesing: City #  234  |  Martapura ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=martapura
# ------------------------
# Proceesing: City #  235  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=castro
# ------------------------
# Proceesing: City #  236  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sao filipe
# ------------------------
# Proceesing: City #  237  |  Raudeberg NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=raudeberg
# ------------------------
# Proceesing: City #  238  |  Atasu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=atasu
# ------------------------
# Proceesing: City #  239  |  Letterkenny IE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=letterkenny
# ------------------------
# Proceesing: City #  240  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=chuy
# ------------------------
# Proceesing: City #  241  |  Farnham GB
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=farnham
# ------------------------
# Proceesing: City #  242  |  Monterey US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=monterey
# ------------------------
# Proceesing: City #  243  |  Corcoran US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=corcoran
# ------------------------
# Proceesing: City #  244  |  Urengoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=urengoy
# City not found, skipping...
# ------------------------
# Proceesing: City #  245  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nikolskoye
# City not found, skipping...
# ------------------------
# Proceesing: City #  246  |  Oussouye SN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=oussouye
# ------------------------
# Proceesing: City #  247  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=portland
# ------------------------
# Proceesing: City #  248  |  Aksu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=aksu
# ------------------------
# Proceesing: City #  249  |  Rocha UY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=rocha
# ------------------------
# Proceesing: City #  250  |  Chicama PE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=chicama
# ------------------------
# Proceesing: City #  251  |  Biak ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=biak
# ------------------------
# Proceesing: City #  252  |  Paamiut GL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=paamiut
# ------------------------
# Proceesing: City #  253  |  Port Macquarie AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port macquarie
# ------------------------
# Proceesing: City #  254  |  Waitati NZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=waitati
# ------------------------
# Proceesing: City #  255  |  Eureka US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=eureka
# ------------------------
# Proceesing: City #  256  |  Kedrovyy RU
# ...
# ------------------------
# Proceesing: City #  448  |  Avanigadda IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=avanigadda
# ------------------------
# Proceesing: City #  449  |  Ambovombe MG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ambovombe
# ------------------------
# Proceesing: City #  450  |  Inuvik CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=inuvik
# ------------------------
# Proceesing: City #  451  |  Mimongo GA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mimongo
# ------------------------
# Proceesing: City #  452  |  Chute-aux-Outardes CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=chute-aux-outardes
# ------------------------
# Proceesing: City #  453  |  Uromi NG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=uromi
# ------------------------
# Proceesing: City #  454  |  Hovd NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hovd
# City not found, skipping...
# ------------------------
# Proceesing: City #  455  |  Young UY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=young
# ------------------------
# Proceesing: City #  456  |  Havelock US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=havelock
# ------------------------
# Proceesing: City #  457  |  Clyde River CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=clyde river
# ------------------------
# Proceesing: City #  458  |  Zuenoula CI
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=zuenoula
# ------------------------
# Proceesing: City #  459  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port hardy
# ------------------------
# Proceesing: City #  460  |  Ballina IE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ballina
# ------------------------
# Proceesing: City #  461  |  Vigrestad NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=vigrestad
# ------------------------
# Proceesing: City #  462  |  Baherden TM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=baherden
# ------------------------
# Proceesing: City #  463  |  Iralaya HN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=iralaya
# ------------------------
# Proceesing: City #  464  |  Flin Flon CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=flin flon
# ------------------------
# Proceesing: City #  465  |  Copiapo CL
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=copiapo
# ------------------------
# Proceesing: City #  466  |  Knevichi RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=knevichi
# ------------------------
# Proceesing: City #  467  |  Port Hedland AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=port hedland
# ------------------------
# Proceesing: City #  468  |  Nanga Eboko CM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nanga eboko
# City not found, skipping...
# ------------------------
# Proceesing: City #  469  |  Kaliua TZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kaliua
# ------------------------
# Proceesing: City #  470  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=san patricio
# ------------------------
# Proceesing: City #  471  |  Torbat-e Jam IR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=torbat-e jam
# ------------------------
# Proceesing: City #  472  |  Yagodnoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=yagodnoye
# ------------------------
# Proceesing: City #  473  |  Goderich CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=goderich
# ------------------------
# Proceesing: City #  474  |  Ixtapa MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ixtapa
# ------------------------
# Proceesing: City #  475  |  Polazna RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=polazna
# ------------------------
# Proceesing: City #  476  |  Kalangala UG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kalangala
# ------------------------
# Proceesing: City #  477  |  Salmon Creek US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=salmon creek
# ------------------------
# Proceesing: City #  478  |  Nago IT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nago
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  479  |  Sao Joao de Pirabas BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sao joao de pirabas
# ------------------------
# Proceesing: City #  480  |  Birao CF
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=birao
# ------------------------
# Proceesing: City #  481  |  Saint-Georges CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=saint-georges
# ------------------------
# Proceesing: City #  482  |  Xalatlaco MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=xalatlaco
# ------------------------
# Proceesing: City #  483  |  Ostersund SE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ostersund
# ------------------------
# Proceesing: City #  484  |  Lufilufi WS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lufilufi
# ------------------------
# Proceesing: City #  485  |  Kaoma ZM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kaoma
# ------------------------
# Proceesing: City #  486  |  Colonia RO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=colonia
# ------------------------
# Proceesing: City #  487  |  Katubao PH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=katubao
# ------------------------
# Proceesing: City #  488  |  Hamilton BM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=hamilton
# ------------------------
# Proceesing: City #  489  |  Juybar IR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=juybar
# ------------------------
# Proceesing: City #  490  |  Mecca SA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mecca
# ------------------------
# Proceesing: City #  491  |  Paraiso MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=paraiso
# ------------------------
# Proceesing: City #  492  |  Palu ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=palu
# ------------------------
# Proceesing: City #  493  |  Tsumeb NA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tsumeb
# ------------------------
# Proceesing: City #  494  |  Chiang Klang TH
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=chiang klang
# ------------------------
# Proceesing: City #  495  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=yumen
# ------------------------
# Proceesing: City #  496  |  Orlik RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=orlik
# ------------------------
# Proceesing: City #  497  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=aklavik
# ------------------------
# Proceesing: City #  498  |  Vilyuysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=vilyuysk
# ------------------------
# Proceesing: City #  499  |  Pingliang CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pingliang
# City not found, skipping...
# ------------------------
# Proceesing: City #  500  |  Alghero IT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=alghero
# ------------------------
# Proceesing: City #  501  |  Muana BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=muana
# ------------------------
# Proceesing: City #  502  |  Mairana BO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=mairana
# ------------------------
# Proceesing: City #  503  |  Gravdal NO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=gravdal
# ------------------------
# Proceesing: City #  504  |  Lensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lensk
# City not found, skipping...
# ------------------------
# Proceesing: City #  505  |  Susanville US
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=susanville
# ------------------------
# Proceesing: City #  506  |  Luganville VU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=luganville
# ------------------------
# Proceesing: City #  507  |  Lagoa PT
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lagoa
# ------------------------
# Proceesing: City #  508  |  Umm Kaddadah SD
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=umm kaddadah
# ------------------------
# Proceesing: City #  509  |  Kysyl-Syr RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kysyl-syr
# ------------------------
# Proceesing: City #  510  |  Magadan RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=magadan
# ------------------------
# Proceesing: City #  511  |  Novyy Urgal RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=novyy urgal
# ------------------------
# Proceesing: City #  512  |  Pangai TO
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=pangai
# ------------------------
# Proceesing: City #  513  |  Solwezi ZM
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=solwezi
# ------------------------
# Proceesing: City #  514  |  Palmer AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=palmer
# City not found, skipping...
# ------------------------
# Proceesing: City #  515  |  Reconquista AR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=reconquista
# ------------------------
# Proceesing: City #  516  |  Barabai ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=barabai
# ------------------------
# Proceesing: City #  517  |  Prokuplje RS
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=prokuplje
# ------------------------
# Proceesing: City #  518  |  Dakoro NE
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=dakoro
# ------------------------
# Proceesing: City #  519  |  Nalagarh IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=nalagarh
# ------------------------
# Proceesing: City #  520  |  Sabla NG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sabla
# ------------------------
# Proceesing: City #  521  |  Adra IN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=adra
# ------------------------
# Proceesing: City #  522  |  Waingapu ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=waingapu
# ------------------------
# Proceesing: City #  523  |  Shuyskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=shuyskoye
# ------------------------
# Proceesing: City #  524  |  Tambovka UA
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=tambovka
# ------------------------
# Proceesing: City #  525  |  Alice Springs AU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=alice springs
# ------------------------
# Proceesing: City #  526  |  Aldan RU
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=aldan
# ------------------------
# Proceesing: City #  527  |  Sorong ID
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=sorong
# ------------------------
# Proceesing: City #  528  |  Olot UZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=olot
# City not found, skipping...
# ------------------------
# Proceesing: City #  529  |  Namatanai PG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=namatanai
# ------------------------
# Proceesing: City #  530  |  Puerto Escondido MX
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=puerto escondido
# ------------------------
# Proceesing: City #  531  |  Guilin CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=guilin
# ------------------------
# Proceesing: City #  532  |  Urucui BR
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=urucui
# ------------------------
# Proceesing: City #  533  |  Ushtobe KZ
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=ushtobe
# ------------------------
# Proceesing: City #  534  |  Kieta PG
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=kieta
# ------------------------
# Proceesing: City #  535  |  Villaviciosa ES
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=villaviciosa
# ------------------------
# Proceesing: City #  536  |  Lishu CN
# http://api.openweathermap.org/data/2.5/weather?appid=a8eff4d0e6e0d337ea17db7b9d6e4c5c&units=imperial&q=lishu

# %%
#print(json.dumps(new_cities_df, indent = 4, sort_keys=True))

# %%
new_cities_df.count()
# Out:
# City           536
# Country        536
# Temperature    536
# Latitude       536
# Longitude      536
# Humidity       536
# Cloudiness     536
# Wind Speed     536
# Date           536
# dtype: int64

# %%
# new_cities_df = new_cities_df.reset_index()
# del new_cities_df["index"]
new_cities_df.head()
# Out:
#              City Country  Temperature  Latitude  Longitude  Humidity  \
# 0  Saint-Philippe      CA        15.78     45.36     -73.48      66.0
# 1          Albany      US        26.94     42.65     -73.75      68.0
# 2          Avarua      CK        84.20    -21.21    -159.78      79.0
# 3       Jamestown      AU        87.50    -33.21     138.60      29.0
# 4        Hermanus      ZA        63.30    -34.42      19.24      94.0
#
#    Cloudiness  Wind Speed          Date
# 0         1.0        2.46  1.551490e+09
# 1         1.0        3.36  1.551489e+09
# 2        76.0        3.36  1.551487e+09
# 3         0.0        7.94  1.551489e+09
# 4         0.0        1.99  1.551489e+09

# %%
new_cities_df.to_csv("Resources/City_Datas.csv")

# %%
now=datetime.datetime.now()
#{datetime.now().strftime('%m/%d/%Y')}

# %% [markdown]
# ### Plotting the Data
#
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Temperature"], c=new_cities_df["Temperature"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {now.strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-30, 100])

# Save the figure
plt.savefig("Resources/Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Humidity"], c=new_cities_df["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity {now.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([0, 110])

# Save the figure
plt.savefig("Resources/Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Cloudiness"], c=new_cities_df["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness {now.strftime('%m/%d/%Y')} ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-20, 110])

# Save the figure
plt.savefig("Resources/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Wind Speed"], c=new_cities_df["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed {now.strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([0, 40])

# Save the figure
plt.savefig("Resources/Latitude_Wind Speed.png")

# Show plot
plt.show()
